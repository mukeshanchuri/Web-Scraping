# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import re

# %%
url = "https://www.franchiseindia.com/business-opportunities/food-and-beverage.m2?sortby=&page=1"

# %%
page = requests.get(url)
page
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(page.text)

# %%
p = soup.find_all("div", class_ = "col-xs-12 col-sm-6 col-md-6 catlistinfo row-no-padding sec-slide-effect")
p
# Out:
# [<div class="col-xs-12 col-sm-6 col-md-6 catlistinfo row-no-padding sec-slide-effect">
#  <div class="comparechk">
#  <input class="brandCompareCheckbox" id="compare0" name="compareCheckbox" onclick="getBrandsForComparison()" type="checkbox" value="FIHL965662"/>
#  <label for="compare0"><span></span></label>
#  </div>
#  <div class="padfb15">
#  <a href="https://www.franchiseindia.com/brands/the-granios.43694" target="_blank">
#  <div class="catimgmobile">
#  <img alt="THE GRANIOS" src="https://franchiseindia.s3.ap-south-1.amazonaws.com/uploads/franchisor/the-granios_2.png"/>
#  </div>
#  </a>
#  <div class="catlisthead">Quick Service Restaurants</div>
#  <div class="catlist">
#  <a href="https://www.franchiseindia.com/brands/the-granios.43694" id="brandnamecategoryFIHL965662" target="_blank">
#                  THE GRANIOS
#              </a>
#  </div>
#  <span id="brandinvestmentFIHL965662" style="display: none;">
#              INR  2 Lac  - 5 Lac
#          </span>
#  </div>
# ...

# %%
q = soup.find_all("div", class_ = "catlist")
q
# Out:
# [<div class="catlist">
#  <a href="https://www.franchiseindia.com/brands/the-granios.43694" id="brandnamecategoryFIHL965662" target="_blank">
#                  THE GRANIOS
#              </a>
#  </div>,
#  <div class="catlist">
#  <a href="https://www.franchiseindia.com/brands/what-a-sandwich.51513" id="brandnamecategoryFIHL403765" target="_blank">
#                  What a Sandwich
#              </a>
#  </div>,
#  <div class="catlist">
#  <a href="https://www.franchiseindia.com/brands/Go69-Pizza.21117" id="brandnamecategoryFIHL9252677" target="_blank">
#                  Go69 Pizza
#              </a>
#  </div>,
#  <div class="catlist">
#  <a href="https://www.franchiseindia.com/brands/chicago-pizza.27821" id="brandnamecategoryFIHL747566" target="_blank">
#                  CHICAGO PIZZA
#              </a>
#  </div>,
#  <div class="catlist">
#  <a href="https://www.franchiseindia.com/brands/brewbakes.20329" id="brandnamecategoryFIHL6269091" target="_blank">
# ...

# %%
data = soup.find_all("div", class_ = "subcat pleft")
data
# Out:
# [<div class="subcat pleft">
#  <span>Establishment year</span>
#                      2013
#                  </div>,
#  <div class="subcat pleft">
#  <span>Investment size</span>
#                      INR  2 Lac  - 5 Lac
#                  </div>,
#  <div class="subcat pleft">
#  <span>Franchise Type</span>
#                          Unit
#                      </div>,
#  <div class="subcat pleft">
#  <span>Establishment year</span>
#                      2013
#                  </div>,
#  <div class="subcat pleft">
#  <span>Investment size</span>
#                      INR  50 K  - 2 Lac
#                  </div>,
#  <div class="subcat pleft">
#  <span>Franchise Type</span>
#                          Unit, Multiunit
#                      </div>,
#  <div class="subcat pleft">
#  <span>Establishment year</span>
#                      2015
#                  </div>,
#  <div class="subcat pleft">
#  <span>Investment size</span>
#                      INR  5 Lac  - 10 Lac
# ...

# %%
data1=soup.find_all("div" , class_ = "commanmbsmobile")#[0].text.replace("\n","").split()[2]
data1
# Out:
# [<div class="commanmbsmobile">
#  <div class="subcat pleft">
#  <span>Establishment year</span>
#                      2013
#                  </div>
#  <div class="subcat pright">
#  <span>Franchising Launch Date</span>
#                      2017
#                  </div>
#  <div class="subcat pleft">
#  <span>Investment size</span>
#                      INR  2 Lac  - 5 Lac
#                  </div>
#  <div class="subcat pright"><span>Space required</span>
#                      200 - 1300
#                  </div>
#  <div class="subcat pleft">
#  <span>Franchise Type</span>
#                          Unit
#                      </div>
#  <div class="subcat pright">
#  <span>Franchise Outlets</span>
#                      10-20
#                  </div>
#  </div>,
#  <div class="commanmbsmobile">
#  <div class="subcat pleft">
#  <span>Establishment year</span>
#                      2013
#                  </div>
#  <div class="subcat pright">
# ...

# %%
data2=soup.find_all("div" , class_ = "commanmbsmobile")#[0].text.replace("\n","")
data2
# Out:
# [<div class="commanmbsmobile">
#  <div class="subcat pleft">
#  <span>Establishment year</span>
#                      2013
#                  </div>
#  <div class="subcat pright">
#  <span>Franchising Launch Date</span>
#                      2017
#                  </div>
#  <div class="subcat pleft">
#  <span>Investment size</span>
#                      INR  2 Lac  - 5 Lac
#                  </div>
#  <div class="subcat pright"><span>Space required</span>
#                      200 - 1300
#                  </div>
#  <div class="subcat pleft">
#  <span>Franchise Type</span>
#                          Unit
#                      </div>
#  <div class="subcat pright">
#  <span>Franchise Outlets</span>
#                      10-20
#                  </div>
#  </div>,
#  <div class="commanmbsmobile">
#  <div class="subcat pleft">
#  <span>Establishment year</span>
#                      2013
#                  </div>
#  <div class="subcat pright">
# ...

# %%
Establishment = []
for i in data1:
    a = i.text
    Establishment.append(a.replace("\n","").split()[2])
Establishment
# Out:
# ['2013',
#  '2013',
#  '2015',
#  '2000',
#  '1998',
#  '2001',
#  '2016',
#  '2010',
#  '2012',
#  '2021',
#  '1980',
#  '2003',
#  '2019',
#  '1950',
#  '2020',
#  '2017',
#  '2018',
#  '1981',
#  '2021',
#  '2017',
#  '2021']

# %%
Company = []
for i in q:
    a = i.text
    b=a.strip()
    Company.append(b.replace("\n",""))
    #c = append(b)
Company
# Out:
# ['What a Sandwich',
#  'THE GRANIOS',
#  'Go69 Pizza',
#  'CHICAGO PIZZA',
#  'U.S. Pizza',
#  'KK Thali by Hotel KK',
#  'Stark Bistro',
#  'Frespresso Hospitality Pvt Ltd',
#  'Sandwich Junction',
#  'AGS MEGA MART LLP',
#  'Punnu Biriyani',
#  'Kathi Express',
#  'Round Slice',
#  'Karim’s',
#  'Scuzo',
#  'Franky Station',
#  'Regional Foods',
#  "Figaro's Italian Pizza",
#  'BTS Coffee India',
#  'Michaels Icecream Burger',
#  'American Burger cafe']

# %%
a.replace("\n","")
# Out:
# '                American Burger cafe            '

# %%
data2=soup.find_all("div" , class_ = "commanmbsmobile")#[0].text.split("INR")[1].split('\n')[0]
data2
# Out:
# [<div class="commanmbsmobile">
#  <div class="subcat pleft">
#  <span>Establishment year</span>
#                      2013
#                  </div>
#  <div class="subcat pright">
#  <span>Franchising Launch Date</span>
#                      2018
#                  </div>
#  <div class="subcat pleft">
#  <span>Investment size</span>
#                      INR  50 K  - 2 Lac
#                  </div>
#  <div class="subcat pright"><span>Space required</span>
#                      200 - 250
#                  </div>
#  <div class="subcat pleft">
#  <span>Franchise Type</span>
#                          Unit, Multiunit
#                      </div>
#  <div class="subcat pright">
#  <span>Franchise Outlets</span>
#                      100-200
#                  </div>
#  </div>,
#  <div class="commanmbsmobile">
#  <div class="subcat pleft">
#  <span>Establishment year</span>
#                      2013
#                  </div>
#  <div class="subcat pright">
# ...

# %%
Investment = []
for i in data2:
    a = i.text
    b = Investment.append(a.split("INR")[1].split('\n')[0])
Investment
# Out:
# ['  50 K  - 2 Lac ',
#  '  2 Lac  - 5 Lac ',
#  '  5 Lac  - 10 Lac ',
#  '  10 Lac  - 20 Lac ',
#  '  20 Lac  - 30 Lac ',
#  '  20 Lac  - 30 Lac ',
#  '  5 Lac  - 10 Lac ',
#  '  10 Lac  - 20 Lac ',
#  '  10 Lac  - 2 Cr ',
#  '  10 Lac  - 20 Lac ',
#  '  10 Lac  - 20 Lac ',
#  '  2 Lac  - 5 Lac ',
#  '  50 Lac  - 1 Cr ',
#  '  50 Lac  - 1 Cr ',
#  '  10 Lac  - 20 Lac ',
#  '  10 Lac  - 20 Lac ',
#  '  1 Cr  - 2 Cr ',
#  '  30 Lac  - 50 Lac ',
#  '  10 Lac  - 20 Lac ',
#  '  5 Lac  - 10 Lac ',
#  '  10 Lac  - 20 Lac ']

# %%
Min_Invest= []
for i in data2:
    a = i.text
    b = Min_Invest.append(a.split("INR")[1].split('\n')[0].split('-')[0])
Min_Invest
# Out:
# ['  50 K  ',
#  '  2 Lac  ',
#  '  5 Lac  ',
#  '  10 Lac  ',
#  '  20 Lac  ',
#  '  20 Lac  ',
#  '  5 Lac  ',
#  '  10 Lac  ',
#  '  10 Lac  ',
#  '  10 Lac  ',
#  '  10 Lac  ',
#  '  2 Lac  ',
#  '  50 Lac  ',
#  '  50 Lac  ',
#  '  10 Lac  ',
#  '  10 Lac  ',
#  '  1 Cr  ',
#  '  30 Lac  ',
#  '  10 Lac  ',
#  '  5 Lac  ',
#  '  10 Lac  ']

# %%
Max_Invest= []
for i in data2:
    a = i.text
    b = Max_Invest.append(a.split("INR")[1].split('\n')[0].split('-')[1])
Max_Invest
# Out:
# [' 2 Lac ',
#  ' 5 Lac ',
#  ' 10 Lac ',
#  ' 20 Lac ',
#  ' 30 Lac ',
#  ' 30 Lac ',
#  ' 10 Lac ',
#  ' 20 Lac ',
#  ' 2 Cr ',
#  ' 20 Lac ',
#  ' 20 Lac ',
#  ' 5 Lac ',
#  ' 1 Cr ',
#  ' 1 Cr ',
#  ' 20 Lac ',
#  ' 20 Lac ',
#  ' 2 Cr ',
#  ' 50 Lac ',
#  ' 20 Lac ',
#  ' 10 Lac ',
#  ' 20 Lac ']

# %%
data2=soup.find_all("div" , class_ = "commanmbsmobile")#[0].text.split("Date")[1].split()[0]
data2
# Out:
# [<div class="commanmbsmobile">
#  <div class="subcat pleft">
#  <span>Establishment year</span>
#                      2013
#                  </div>
#  <div class="subcat pright">
#  <span>Franchising Launch Date</span>
#                      2018
#                  </div>
#  <div class="subcat pleft">
#  <span>Investment size</span>
#                      INR  50 K  - 2 Lac
#                  </div>
#  <div class="subcat pright"><span>Space required</span>
#                      200 - 250
#                  </div>
#  <div class="subcat pleft">
#  <span>Franchise Type</span>
#                          Unit, Multiunit
#                      </div>
#  <div class="subcat pright">
#  <span>Franchise Outlets</span>
#                      100-200
#                  </div>
#  </div>,
#  <div class="commanmbsmobile">
#  <div class="subcat pleft">
#  <span>Establishment year</span>
#                      2013
#                  </div>
#  <div class="subcat pright">
# ...

# %%
Launching = []
for i in data2:
    a = i.text
    b = Launching.append(a.split("Date")[1].split()[0])
Launching
# Out:
# ['2018',
#  '2017',
#  '2016',
#  '2007',
#  '2002',
#  '2022',
#  '2016',
#  '2010',
#  '2018',
#  '2022',
#  '2022',
#  '2003',
#  '2020',
#  '2018',
#  '2020',
#  '2022',
#  '2020',
#  '2001',
#  '2021',
#  '2019',
#  '2022']

# %%
data2=soup.find_all("div" , class_ = "commanmbsmobile")#[0].text.split('required')[1].split('\n')[1].split()[0]
data2
# Out:
# [<div class="commanmbsmobile">
#  <div class="subcat pleft">
#  <span>Establishment year</span>
#                      2013
#                  </div>
#  <div class="subcat pright">
#  <span>Franchising Launch Date</span>
#                      2018
#                  </div>
#  <div class="subcat pleft">
#  <span>Investment size</span>
#                      INR  50 K  - 2 Lac
#                  </div>
#  <div class="subcat pright"><span>Space required</span>
#                      200 - 250
#                  </div>
#  <div class="subcat pleft">
#  <span>Franchise Type</span>
#                          Unit, Multiunit
#                      </div>
#  <div class="subcat pright">
#  <span>Franchise Outlets</span>
#                      100-200
#                  </div>
#  </div>,
#  <div class="commanmbsmobile">
#  <div class="subcat pleft">
#  <span>Establishment year</span>
#                      2013
#                  </div>
#  <div class="subcat pright">
# ...

# %%
space = []
for i in data2:
    a = i.text
    b = space.append(a.split('required')[1].split('\n')[1].strip())
space
# Out:
# ['200 - 250',
#  '200 - 1300',
#  '100 - 800',
#  '100 - 150',
#  '250 - 1000',
#  '1000 - 3500',
#  '100 - 5000',
#  '100 - 1000',
#  '100 - 1000',
#  '300 - 2000',
#  '200 - 400',
#  '100 - 400',
#  '800 - 1000',
#  '250 - 2000',
#  '100 - 300',
#  '250 - 400',
#  '1200 - 1500',
#  '-N/A-',
#  '00 - 000',
#  '100 - 500',
#  '150 - 300']

# %%
minspace = []
for i in data2:
    a = i.text
    minspace.append(a.split('required')[1].split('\n')[1].split()[0])
minspace
# Out:
# ['200',
#  '200',
#  '100',
#  '100',
#  '250',
#  '1000',
#  '100',
#  '100',
#  '100',
#  '300',
#  '200',
#  '100',
#  '800',
#  '250',
#  '100',
#  '250',
#  '1200',
#  '-N/A-',
#  '00',
#  '100',
#  '150']

# %%
data2=soup.find_all("div" , class_ = "commanmbsmobile")#[0].text.split('required')[1].split('\n')[1].split()[2]
data2
# Out:
# [<div class="commanmbsmobile">
#  <div class="subcat pleft">
#  <span>Establishment year</span>
#                      2013
#                  </div>
#  <div class="subcat pright">
#  <span>Franchising Launch Date</span>
#                      2018
#                  </div>
#  <div class="subcat pleft">
#  <span>Investment size</span>
#                      INR  50 K  - 2 Lac
#                  </div>
#  <div class="subcat pright"><span>Space required</span>
#                      200 - 250
#                  </div>
#  <div class="subcat pleft">
#  <span>Franchise Type</span>
#                          Unit, Multiunit
#                      </div>
#  <div class="subcat pright">
#  <span>Franchise Outlets</span>
#                      100-200
#                  </div>
#  </div>,
#  <div class="commanmbsmobile">
#  <div class="subcat pleft">
#  <span>Establishment year</span>
#                      2013
#                  </div>
#  <div class="subcat pright">
# ...

# %%
maxspace = []
for i in data2:
    a = i.text
    maxspace.append(a.split('required')[1].split('\n')[1].split())
maxspace
# Out:
# [['200', '-', '250'],
#  ['200', '-', '1300'],
#  ['100', '-', '800'],
#  ['100', '-', '150'],
#  ['250', '-', '1000'],
#  ['1000', '-', '3500'],
#  ['100', '-', '5000'],
#  ['100', '-', '1000'],
#  ['100', '-', '1000'],
#  ['300', '-', '2000'],
#  ['200', '-', '400'],
#  ['100', '-', '400'],
#  ['800', '-', '1000'],
#  ['250', '-', '2000'],
#  ['100', '-', '300'],
#  ['250', '-', '400'],
#  ['1200', '-', '1500'],
#  ['-N/A-'],
#  ['00', '-', '000'],
#  ['100', '-', '500'],
#  ['150', '-', '300']]

# %%
data3=soup.find_all("div",class_="commanmbsmobile")#[0].text.split('Franchise Outlets')[0]
data3
# Out:
# [<div class="commanmbsmobile">
#  <div class="subcat pleft">
#  <span>Establishment year</span>
#                      2013
#                  </div>
#  <div class="subcat pright">
#  <span>Franchising Launch Date</span>
#                      2018
#                  </div>
#  <div class="subcat pleft">
#  <span>Investment size</span>
#                      INR  50 K  - 2 Lac
#                  </div>
#  <div class="subcat pright"><span>Space required</span>
#                      200 - 250
#                  </div>
#  <div class="subcat pleft">
#  <span>Franchise Type</span>
#                          Unit, Multiunit
#                      </div>
#  <div class="subcat pright">
#  <span>Franchise Outlets</span>
#                      100-200
#                  </div>
#  </div>,
#  <div class="commanmbsmobile">
#  <div class="subcat pleft">
#  <span>Establishment year</span>
#                      2013
#                  </div>
#  <div class="subcat pright">
# ...

# %%
ftype = []
for i in data3:
    a = i.text
    ftype.append(a.split('Franchise')[1].split('\n')[1].strip())
ftype
# Out:
# ['Unit, Multiunit',
#  'Unit',
#  'Unit',
#  'Unit, Multiunit',
#  'Unit',
#  'Unit',
#  'Unit, Multiunit',
#  'Unit, Multiunit',
#  'Unit, Multiunit',
#  'Unit, Multiunit',
#  'Unit',
#  'Unit',
#  'Unit',
#  'Unit',
#  'Unit',
#  'Unit',
#  'Unit',
#  'Unit',
#  'Unit',
#  'Unit, Multiunit',
#  'Unit']

# %%
data4 = soup.find_all("div" , class_ = "subcat")[0].text.split()
data4
# Out:
# ['Locations',
#  'looking',
#  'for',
#  'expansion',
#  'Delhi,',
#  'Haryana,',
#  'Himachal',
#  'Pradesh,',
#  '....',
#  '+',
#  '32',
#  'more']

# %%
data2=soup.find_all("div" , class_ = "commanmbsmobile")#[4].text.split('Franchise')[2].split('\n')[1].strip()
data2
# Out:
# [<div class="commanmbsmobile">
#  <div class="subcat pleft">
#  <span>Establishment year</span>
#                      2013
#                  </div>
#  <div class="subcat pright">
#  <span>Franchising Launch Date</span>
#                      2018
#                  </div>
#  <div class="subcat pleft">
#  <span>Investment size</span>
#                      INR  50 K  - 2 Lac
#                  </div>
#  <div class="subcat pright"><span>Space required</span>
#                      200 - 250
#                  </div>
#  <div class="subcat pleft">
#  <span>Franchise Type</span>
#                          Unit, Multiunit
#                      </div>
#  <div class="subcat pright">
#  <span>Franchise Outlets</span>
#                      100-200
#                  </div>
#  </div>,
#  <div class="commanmbsmobile">
#  <div class="subcat pleft">
#  <span>Establishment year</span>
#                      2013
#                  </div>
#  <div class="subcat pright">
# ...

# %%
outlets = []
for i in data2:
    a = i.text
    outlets.append(a.split('Franchise')[2].split('\n')[1].strip())
outlets
# Out:
# ['100-200',
#  '10-20',
#  '50-100',
#  '100-200',
#  '50-100',
#  'Less than 10',
#  '10-20',
#  '20-50',
#  '20-50',
#  'Less than 10',
#  'Less than 10',
#  '20-50',
#  'Less than 10',
#  '20-50',
#  'Less than 10',
#  'Less than 10',
#  'Less than 10',
#  '200-500',
#  'Less than 10',
#  '20-50',
#  'Less than 10']

# %%
r = soup.find_all('div', class_ = "catdright pad20")#[0].text.split('Headquarter')[1].split('\n')[1].strip()
r
# Out:
# [<div class="catdright pad20">
#  <a href="https://www.franchiseindia.com/brands/what-a-sandwich.51513" id="brandnamecategoryFIHL403765" target="_blank"><div class="catimg"><img alt="What a Sandwich" src="https://franchiseindia.s3.ap-south-1.amazonaws.com/uploads/franchisor/what-a-sandwich_1.jpg"/></div></a>
#  <div class="subcat"><span>Investment size</span>
#                  INR  50 K  - 2 Lac
#              </div>
#  <div class="subcat"><span>Space required</span>
#                  200 - 250
#              </div>
#  <div class="subcat">
#  <span>Franchise Outlets</span>
#                  100-200
#              </div>
#  <div class="subcat"><span>Franchise Type</span>                                        Unit, Multiunit
#                  </div>
#  <div class="subcat">
#  <span>Headquarter</span>
#                  Pune
#              </div>
#  </div>,
#  <div class="catdright pad20">
# ...

# %%
hq = []
for i in r:
    a = i.text
    hq.append(a.split('Headquarter')[1].split('\n')[1].strip())
hq
# Out:
# ['Pune',
#  'khammam',
#  'Lucknow',
#  'New delhi',
#  'Bangalore Urban District',
#  'Rajkot',
#  'Bhubaneswar',
#  'vapi',
#  'Pune',
#  'Ghaziabad',
#  'New delhi',
#  'Dehradun',
#  'Ahmedabad',
#  'New delhi',
#  'New delhi',
#  'Vadodara',
#  'Thane',
#  'Faridabad',
#  'Noida',
#  'Bangalore',
#  'Delhi']

# %%
len(hq)
# Out:
# 21

# %% [markdown]
# # DataFrame

# %% [markdown]
# #### *Food and Bevarages*

# %%
Company = []
Establishment = []
Launching = []
Investment= []
outlets = []
space[]
hq = []


for i in range(1,7):
    url = "https://www.franchiseindia.com/business-opportunities/food-and-beverage.m2?sortby=&page="+str(i)
    print(url)
    
    page = requests.get(url)
    soup = BeautifulSoup(page.text)
    data = soup.find_all("div" , class_ = "commanmbsmobile")
    location = soup.find_all('div', class_ = "catdright pad20")
    companyname = soup.find_all("div", class_ = "catlist")
    
    for i in data:
        a = i.text
        Establishment.append(a.replace("\n","").split()[2])
        
    for i in companyname:
        a = i.text
        b= a.strip()
        Company.append(b.replace("\n",""))
        
    for i in data2:
        a = i.text
        b = space.append(a.split('required')[1].split('\n')[1].strip())

    for i in data:
        a = i.text
        b = Investment.append(a.split("INR")[1].split('\n')[0])
    
    for i in data:
        a = i.text
        b = space.append(a.split('required')[1].split('\n')[1].strip())
           
    for i in data:
        a = i.text
        Launching.append(a.split("Date")[1].split()[0])
        
    for i in data:
        a = i.text
        outlets.append(a.split('Franchise')[2].split('\n')[1].strip())    

    for i in location:
        a = i.text
        hq.append(a.split('Headquarter')[1].split('\n')[1].strip())
# Out:
# https://www.franchiseindia.com/business-opportunities/food-and-beverage.m2?sortby=&page=1
# https://www.franchiseindia.com/business-opportunities/food-and-beverage.m2?sortby=&page=2
# https://www.franchiseindia.com/business-opportunities/food-and-beverage.m2?sortby=&page=3
# https://www.franchiseindia.com/business-opportunities/food-and-beverage.m2?sortby=&page=4
# https://www.franchiseindia.com/business-opportunities/food-and-beverage.m2?sortby=&page=5
# https://www.franchiseindia.com/business-opportunities/food-and-beverage.m2?sortby=&page=6

# %%
b = {"Company": Company,
    "Establishing Year": Establishment,
     "Launching Year": Launching,
     "Investment" : Investment,
     "Space Required" : space,
    "Outlets": outlets,
    "Headquarter" : hq}

# %%
print(len(Company))
print(len(Establishment))
print(len(Launching))
print(len(Min_Invest))
print(len(Max_Invest))
print(len(outlets))
print(len(minspace))
print(len(maxspace))
print(len(hq))
# Out:
# 126
# 126
# 126
# 126
# 126
# 126
# 126
# 126
# 126

# %%
bf = pd.DataFrame(b)
bf
# Out:
#                                    Company Establishing Year Launching Year  \
# 0                          What a Sandwich              2013           2018
# 1                               Go69 Pizza              2015           2016
# 2                              THE GRANIOS              2013           2017
# 3                            CHICAGO PIZZA              2000           2007
# 4                                Brewbakes              2014           2015
# ..                                     ...               ...            ...
# 121  Candle Light Date N Dinner Restaurant              2014           2022
# 122                  La Pizza Parkway Cafe              2020           2022
# 123                        KUDRATI KAHUMBO              2000           2022
# 124                    Apna Fal & ShakeSee              2019           2022
# 125               Cafe Choco Craze Pvt Ltd              2010           2012
#
# ...

# %%
bf.describe(include = 'all')
# Out:
#                 Company Establishing Year Launching Year Minimum Investment  \
# count               126               126            126                126
# unique              126                37             20                 10
# top     What a Sandwich              2020           2022           10 Lac
# freq                  1                17             65                 47
#
#        Maximum Investment       Outlets Minimum Space (in sft)  \
# count                 126           126                    126
# unique                 10             6                     27
# top               20 Lac   Less than 10                    100
# freq                   46            85                     21
#
#        Maximum Space (in sft) Headquarter
# count                     126         126
# unique                     35          56
# top                       500   Ahmedabad
# freq                       13          21

# %%
bf.head()
# Out:
#            Company Establishing Year Launching Year Minimum Investment  \
# 0  What a Sandwich              2013           2018             50 K
# 1       Go69 Pizza              2015           2016            5 Lac
# 2      THE GRANIOS              2013           2017            2 Lac
# 3    CHICAGO PIZZA              2000           2007           10 Lac
# 4       U.S. Pizza              1998           2002           20 Lac
#
#   Maximum Investment  Outlets Minimum Space (in sft) Maximum Space (in sft)  \
# 0             2 Lac   100-200                    200                    250
# 1            10 Lac    50-100                    100                    800
# 2             5 Lac     10-20                    200                   1300
# 3            20 Lac   100-200                    100                    150
# 4            30 Lac    50-100                    250                   1000
#
#                 Headquarter
# 0                      Pune
# 1                   Lucknow
# ...

# %%
bf['Outlets'].value_counts()
# Out:
# Less than 10    85
# 100-200         15
# 20-50           10
# 10-20            8
# 50-100           6
# 200-500          2
# Name: Outlets, dtype: int64

# %%
bf['Launching Year'].value_counts()
# Out:
# 2022    65
# 2020    17
# 2021    11
# 2018     6
# 2019     5
# 2017     4
# 2014     2
# 2009     2
# 2016     2
# 2001     2
# 2003     1
# 2010     1
# 2004     1
# 2000     1
# 2015     1
# 2002     1
# 2007     1
# 2012     1
# 2005     1
# 1991     1
# Name: Launching Year, dtype: int64

# %% [markdown]
# ### *Automotive*

# %%
Company = []
Establishment = []
Launching = []
Investment= []
outlets = []
space = []
hq = []


for i in range(1,20):
    url = "https://www.franchiseindia.com/business-opportunities/automotive.m8?sortby=&page="+str(i)
    print(url)
    
    page = requests.get(url)
    soup = BeautifulSoup(page.text)
    data = soup.find_all("div" , class_ = "commanmbsmobile")
    location = soup.find_all('div', class_ = "catdright pad20")
    companyname = soup.find_all("div", class_ = "catlist")
    
    for i in data:
        a = i.text
        Establishment.append(a.replace("\n","").split()[2])
        
    for i in companyname:
        a = i.text
        b= a.strip()
        Company.append(b.replace("\n",""))
           
    for i in data:
        a = i.text
        b = space.append(a.split('required')[1].split('\n')[1].strip())

    for i in data:
        a = i.text
        b = Investment.append(a.split("INR")[1].split('\n')[0])
    
    for i in data:
        a = i.text
        Launching.append(a.split("Date")[1].split()[0])
        
    for i in data:
        a = i.text
        outlets.append(a.split('Outlets')[1].strip())    

    for i in location:
        a = i.text
        hq.append(a.split('Headquarter')[1].split('\n')[1].strip())
# Out:
# https://www.franchiseindia.com/business-opportunities/automotive.m8?sortby=&page=1
# https://www.franchiseindia.com/business-opportunities/automotive.m8?sortby=&page=2
# https://www.franchiseindia.com/business-opportunities/automotive.m8?sortby=&page=3
# https://www.franchiseindia.com/business-opportunities/automotive.m8?sortby=&page=4
# https://www.franchiseindia.com/business-opportunities/automotive.m8?sortby=&page=5
# https://www.franchiseindia.com/business-opportunities/automotive.m8?sortby=&page=6
# https://www.franchiseindia.com/business-opportunities/automotive.m8?sortby=&page=7
# https://www.franchiseindia.com/business-opportunities/automotive.m8?sortby=&page=8
# https://www.franchiseindia.com/business-opportunities/automotive.m8?sortby=&page=9
# https://www.franchiseindia.com/business-opportunities/automotive.m8?sortby=&page=10
# https://www.franchiseindia.com/business-opportunities/automotive.m8?sortby=&page=11
# ...

# %%
e ={"Company": Company,
    "Establishing Year": Establishment,
     "Launching Year": Launching,
     "Investment" : Investment,
     "Space Required" : space,
    "Outlets": outlets,
    "Headquarter" : hq}

# %%
print(len(Company))
print(len(Establishment))
print(len(Launching))
print(len(Min_Invest))
print(len(Max_Invest))
print(len(outlets))
print(len(minspace))
print(len(maxspace))
print(len(hq))
# Out:
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42
# 42

# %%
ef = pd.DataFrame(e)
ef
# Out:
#                                         Company Establishing Year  \
# 0                                 ZEON charging              2019
# 1                                   FILMSHOPPEE              2006
# 2                                      Servizzy              2020
# 3                                         Tirex              2017
# 4                                        ONYXAA              2016
# 5                                         Credr              2015
# 6                                     Permagard              1998
# 7                                     Chargepod              2022
# 8                                 Bharat Cycles              2011
# 9                                Eco Rent a Car              1974
# 10     Bounce Infinity – Battery Swapping Infra              2018
# 11                                  Speed Force              2013
# 12                                 Serviceforce              2011
# ...

# %%
ef.describe(include = 'all')

# %%
ef.head()
# Out:
#                                     Company Establishing Year Launching Year  \
# 0  Bounce Infinity – Battery Swapping Infra              2018           2018
# 1                            Zuink Retrofit              2021           2021
# 2                                  Servizzy              2020           2022
# 3                               FILMSHOPPEE              2006           2022
# 4                                 Permagard              1998           2022
#
#   Minimum Investment Maximum Investment       Outlets Minimum Space (in sft)  \
# 0            2 Lac               5 Lac   Less than 10                     10
# 1            5 Lac              10 Lac   Less than 10                    350
# 2           10 Lac              20 Lac   Less than 10                   1800
# 3           30 Lac              50 Lac   Less than 10                   1300
# 4           30 Lac              50 Lac          10-20                   1500
#
#   Maximum Space (in sft) Headquarter
# ...

# %% [markdown]
# ### *Beauty and Health*

# %%
Company = []
Establishment = []
Launching = []
Investment= []
outlets = []
space = []
hq = []


for i in range(1,20):
    url = "https://www.franchiseindia.com/business-opportunities/beauty-and-health.m1?sortby=&page="+str(i)
    print(url)
    
    page = requests.get(url)
    soup = BeautifulSoup(page.text)
    data = soup.find_all("div" , class_ = "commanmbsmobile")
    location = soup.find_all('div', class_ = "catdright pad20")
    companyname = soup.find_all("div", class_ = "catlist")
    
    for i in data:
        a = i.text
        Establishment.append(a.replace("\n","").split()[2])
        
    for i in companyname:
        a = i.text
        b= a.strip()
        Company.append(b.replace("\n",""))
        
    for i in data:
        a = i.text
        b = space.append(a.split('required')[1].split('\n')[1].strip())

    for i in data:
        a = i.text
        b = Investment.append(a.split("INR")[1].split('\n')[0])
    
    for i in data:
        a = i.text
        Launching.append(a.split("Date")[1].split()[0])
        
    for i in data:
        a = i.text
        outlets.append(a.split('Outlets')[1].strip())

    for i in location:
        a = i.text
        hq.append(a.split('Headquarter')[1].split('\n')[1].strip())
# Out:
# https://www.franchiseindia.com/business-opportunities/beauty-and-health.m1?sortby=&page=1
# https://www.franchiseindia.com/business-opportunities/beauty-and-health.m1?sortby=&page=2
# https://www.franchiseindia.com/business-opportunities/beauty-and-health.m1?sortby=&page=3
# https://www.franchiseindia.com/business-opportunities/beauty-and-health.m1?sortby=&page=4
# https://www.franchiseindia.com/business-opportunities/beauty-and-health.m1?sortby=&page=5
# https://www.franchiseindia.com/business-opportunities/beauty-and-health.m1?sortby=&page=6
# https://www.franchiseindia.com/business-opportunities/beauty-and-health.m1?sortby=&page=7
# https://www.franchiseindia.com/business-opportunities/beauty-and-health.m1?sortby=&page=8
# https://www.franchiseindia.com/business-opportunities/beauty-and-health.m1?sortby=&page=9
# https://www.franchiseindia.com/business-opportunities/beauty-and-health.m1?sortby=&page=10
# ...

# %%
f = {"Company": Company,
    "Establishing Year": Establishment,
     "Launching Year": Launching,
     "Investment" : Investment,
     "Space Required" : space,
    "Outlets": outlets,
    "Headquarter" : hq}

# %%
print(len(Company))
print(len(Establishment))
print(len(Launching))
print(len(Min_Invest))
print(len(Max_Invest))
print(len(outlets))
print(len(minspace))
print(len(maxspace))
print(len(hq))
# Out:
# 90
# 90
# 90
# 90
# 90
# 90
# 90
# 90
# 90

# %%
ff = pd.DataFrame(f)
ff
# Out:
#                                               Company Establishing Year  \
# 0                                     Studio99 Salons              2017
# 1                 JAWED HABIB HAIR AND BEAUTY LIMITED              2006
# 2                                               JUICE              2000
# 3                                     The Man Company              2015
# 4                           Jean Claude Olivier India              2019
# ..                                                ...               ...
# 86                  Medlife Pharma healthcare Pvt Ltd              2014
# 87                                      Framekart.com              1995
# 88  Max Lab, A Division of Max Healthcare Institut...              2016
# 89                                         NephroPlus              2009
# 90                                         Ayouthveda              2020
#
#    Launching Year           Investment Space Required       Outlets  \
# ...

# %%
ff.describe(include = 'all')
# Out:
#                 Company Establishing Year Launching Year           Investment  \
# count                91                91             91                   91
# unique               91                28             19                   11
# top     Studio99 Salons              2017           2022    10 Lac  - 20 Lac
# freq                  1                 9             29                   26
#
#        Space Required       Outlets Headquarter
# count              91            91          91
# unique             64            12          43
# top             -N/A-  Less than 10   Faridabad
# freq                9            54          10

# %%
ff.head()
# Out:
#                                Company Establishing Year Launching Year  \
# 0  JAWED HABIB HAIR AND BEAUTY LIMITED              2006           2009
# 1                                JUICE              2000           2003
# 2                           Ozone Yoga              2017           2022
# 3                            PharmEasy              1995           2022
# 4                               Beardo              2015           2015
#
#   Minimum Investment Maximum Investment       Outlets Minimum Space (in sft)  \
# 0           30 Lac              50 Lac       500-1000                    500
# 1           30 Lac              50 Lac          20-50                   1200
# 2           10 Lac              20 Lac   Less than 10                   1500
# 3             50 K               2 Lac          20-50                    150
# 4            5 Lac              10 Lac   Less than 10                     80
#
#   Maximum Space (in sft) Headquarter
# ...

# %% [markdown]
# ### *Sports, Fitness and Entertainment*

# %%
Company = []
Establishment = []
Launching = []
Investment= []
outlets = []
space = []
hq = []


for i in range(1,20):
    url = "https://www.franchiseindia.com/business-opportunities/sports-fitness-and-entertainment.m11?sortby=&page="+str(i)
    print(url)
    
    page = requests.get(url)
    soup = BeautifulSoup(page.text)
    data = soup.find_all("div" , class_ = "commanmbsmobile")
    location = soup.find_all('div', class_ = "catdright pad20")
    companyname = soup.find_all("div", class_ = "catlist")
    
    for i in data:
        a = i.text
        Establishment.append(a.replace("\n","").split()[2])
        
    for i in companyname:
        a = i.text
        b= a.strip()
        Company.append(b.replace("\n",""))
           
    for i in data:
        a = i.text
        b = space.append(a.split('required')[1].split('\n')[1].strip())

    for i in data:
        a = i.text
        b = Investment.append(a.split("INR")[1].split('\n')[0])
    
    for i in data:
        a = i.text
        Launching.append(a.split("Date")[1].split()[0])
        
    for i in data:
        a = i.text
        outlets.append(a.split('Outlets')[1].strip())    
        

    for i in location:
        a = i.text
        hq.append(a.split('Headquarter')[1].split('\n')[1].strip())
# Out:
# https://www.franchiseindia.com/business-opportunities/sports-fitness-and-entertainment.m11?sortby=&page=1
# https://www.franchiseindia.com/business-opportunities/sports-fitness-and-entertainment.m11?sortby=&page=2
# https://www.franchiseindia.com/business-opportunities/sports-fitness-and-entertainment.m11?sortby=&page=3
# https://www.franchiseindia.com/business-opportunities/sports-fitness-and-entertainment.m11?sortby=&page=4
# https://www.franchiseindia.com/business-opportunities/sports-fitness-and-entertainment.m11?sortby=&page=5
# https://www.franchiseindia.com/business-opportunities/sports-fitness-and-entertainment.m11?sortby=&page=6
# https://www.franchiseindia.com/business-opportunities/sports-fitness-and-entertainment.m11?sortby=&page=7
# https://www.franchiseindia.com/business-opportunities/sports-fitness-and-entertainment.m11?sortby=&page=8
# https://www.franchiseindia.com/business-opportunities/sports-fitness-and-entertainment.m11?sortby=&page=9
# ...

# %%
g = {"Company": Company,
    "Establishing Year": Establishment,
     "Launching Year": Launching,
     "Investment" : Investment,
     "Space Required" : space,
    "Outlets": outlets,
    "Headquarter" : hq}

# %%
print(len(Company))
print(len(Establishment))
print(len(Launching))
print(len(Min_Invest))
print(len(Max_Invest))
print(len(outlets))
print(len(minspace))
print(len(maxspace))
print(len(hq))
# Out:
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14
# 14

# %%
gf = pd.DataFrame(g)
gf
# Out:
#                          Company Establishing Year Launching Year  \
# 0              Dazzle SportsWear              2006           2020
# 1                          Alcis              2018           2018
# 2                   Your Fitness              2021           2021
# 3                   Sporty Beans              2009           2022
# 4                   ACME Fitness              1998           2022
# 5              Funplex Game zone              2016           2022
# 6                   Swing & Spin              2019           2022
# 7                    New Fangled              2019           2022
# 8     THE CONNPLEX SMART THEATRE              2009           2019
# 9           Eos Cinemas Pvt. Ltd              2013           2015
# 10  SGL MINIPLEX PRIVATE LIMITED              2020           2020
# 11                      ResQRoom              2016           2018
# 12      House of Fitness pvt ltd              2012           2012
# ...

# %%
gf.describe(include = 'all')
# Out:
#              Company Establishing Year Launching Year Minimum Investment  \
# count             14                14             14                 14
# unique            14                10              7                  7
# top     Swing & Spin              2016           2022           50 Lac
# freq               1                 3              5                  4
#
#        Maximum Investment       Outlets Minimum Space (in sft)  \
# count                  14            14                     14
# unique                  7             5                     11
# top                 1 Cr   Less than 10                    500
# freq                    4             9                      3
#
#        Maximum Space (in sft) Headquarter
# count                      14          14
# unique                     14          12
# top               1000 - 1200     Gurgaon
# freq                        1           2

# %%
gf.head()
# Out:
#              Company Establishing Year Launching Year Minimum Investment  \
# 0       Swing & Spin              2019           2022           10 Lac
# 1       Sporty Beans              2009           2022            5 Lac
# 2              Alcis              2018           2018           20 Lac
# 3  Funplex Game zone              2016           2022             2 Cr
# 4        New Fangled              2019           2022             1 Cr
#
#   Maximum Investment       Outlets Minimum Space (in sft)  \
# 0            20 Lac   Less than 10                   1000
# 1            10 Lac         50-100                   1500
# 2            30 Lac   Less than 10                    500
# 3              5 Cr   Less than 10                   6000
# 4              2 Cr   Less than 10                   5000
#
#   Maximum Space (in sft) Headquarter
# 0            1000 - 1200     Gurgaon
# 1            1500 - 1500        Pune
# 2             500 - 1000       Dadri
# ...

# %% [markdown]
# ### *Education*

# %%
Company = []
Establishment = []
Launching = []
Investment= []
outlets = []
space = []
hq = []


for i in range(1,20):
    url = "https://www.franchiseindia.com/business-opportunities/education.m3?sortby=&page="+str(i)
    print(url)
    
    page = requests.get(url)
    soup = BeautifulSoup(page.text)
    data = soup.find_all("div" , class_ = "commanmbsmobile")
    location = soup.find_all('div', class_ = "catdright pad20")
    companyname = soup.find_all("div", class_ = "catlist")
    
    for i in data:
        a = i.text
        Establishment.append(a.replace("\n","").split()[2])
        
    for i in companyname:
        a = i.text
        b= a.strip()
        Company.append(b.replace("\n",""))
           
    for i in data:
        a = i.text
        b = space.append(a.split('required')[1].split('\n')[1].strip())

    for i in data:
        a = i.text
        b = Investment.append(a.split("INR")[1].split('\n')[0])

    for i in data:
        a = i.text
        Launching.append(a.split("Date")[1].split()[0])
        
    for i in data:
        a = i.text
        outlets.append(a.split('Outlets')[1].strip())    
        

    for i in location:
        a = i.text
        hq.append(a.split('Headquarter')[1].split('\n')[1].strip())
# Out:
# https://www.franchiseindia.com/business-opportunities/education.m3?sortby=&page=1
# https://www.franchiseindia.com/business-opportunities/education.m3?sortby=&page=2
# https://www.franchiseindia.com/business-opportunities/education.m3?sortby=&page=3
# https://www.franchiseindia.com/business-opportunities/education.m3?sortby=&page=4
# https://www.franchiseindia.com/business-opportunities/education.m3?sortby=&page=5
# https://www.franchiseindia.com/business-opportunities/education.m3?sortby=&page=6
# https://www.franchiseindia.com/business-opportunities/education.m3?sortby=&page=7
# https://www.franchiseindia.com/business-opportunities/education.m3?sortby=&page=8
# https://www.franchiseindia.com/business-opportunities/education.m3?sortby=&page=9
# https://www.franchiseindia.com/business-opportunities/education.m3?sortby=&page=10
# https://www.franchiseindia.com/business-opportunities/education.m3?sortby=&page=11
# ...

# %%
h = {"Company": Company,
    "Establishing Year": Establishment,
     "Launching Year": Launching,
     "Investment" : Investment,
     "Space Required" : space,
    "Outlets": outlets,
    "Headquarter" : hq}

# %%
print(len(Company))
print(len(Establishment))
print(len(Launching))
print(len(Min_Invest))
print(len(Max_Invest))
print(len(outlets))
print(len(minspace))
print(len(maxspace))
print(len(hq))
# Out:
# 75
# 75
# 75
# 75
# 75
# 75
# 75
# 75
# 75

# %%
hf = pd.DataFrame(h)
hf
# Out:
#                                       Company Establishing Year  \
# 0                                      Kidzee              2000
# 1                     Red SchoolHouse Pte Ltd              2004
# 2   Montana International Preschool & Daycare              2014
# 3                     Academy of Broadcasting              2003
# 4                           Chisel Montessori              2013
# ..                                        ...               ...
# 71                                Nava Vision              2015
# 72                 Sansrev Global Edu Pvt Ltd              2001
# 73                         wonder play school              2005
# 74                 Delhi Public School Global              2017
# 75                   Change Lifestyle Pvt Ltd              2010
#
#    Launching Year           Investment Space Required       Outlets  \
# 0            2020    10 Lac  - 20 Lac     2500 - 3000      500-1000
# ...

# %%
hf.describe(include = 'all')
# Out:
#        Company Establishing Year Launching Year Minimum Investment  \
# count       75                75             75                 75
# unique      75                28             21                 11
# top     Kidzee              2018           2022           10 Lac
# freq         1                 8             18                 18
#
#        Maximum Investment       Outlets Minimum Space (in sft)  \
# count                  75            75                     75
# unique                 11             9                     28
# top               20 Lac   Less than 10                   1500
# freq                   19            38                     15
#
#        Maximum Space (in sft) Headquarter
# count                      75          75
# unique                     54          43
# top               1500 - 2000      Mumbai
# freq                        7          17

# %%
hf.head()
# Out:
#                                      Company Establishing Year Launching Year  \
# 0                                     Kidzee              2000           2020
# 1  Montana International Preschool & Daycare              2014           2017
# 2                                    Skoodos              2022           2022
# 3                                Udayan Kidz              2017           2021
# 4                          Pearls Montessori              2012           2021
#
#   Minimum Investment Maximum Investment       Outlets Minimum Space (in sft)  \
# 0           10 Lac              20 Lac       500-1000                   2500
# 1           20 Lac              30 Lac   Less than 10                    500
# 2            2 Lac               5 Lac   Less than 10                    000
# 3           20 Lac              30 Lac   Less than 10                   2000
# 4           30 Lac              50 Lac   Less than 10                   3500
#
# ...

# %% [markdown]
# ### *Fashion*

# %%
Company = []
Establishment = []
Launching = []
Investment= []
outlets = []
space = []
hq = []

for i in range(1,20):
    url = "https://www.franchiseindia.com/business-opportunities/fashion.m10?sortby=&page="+str(i)
    print(url)
    
    page = requests.get(url)
    soup = BeautifulSoup(page.text)
    data = soup.find_all("div" , class_ = "commanmbsmobile")
    location = soup.find_all('div', class_ = "catdright pad20")
    companyname = soup.find_all("div", class_ = "catlist")
    
    for i in data:
        a = i.text
        Establishment.append(a.replace("\n","").split()[2])
        
    for i in companyname:
        a = i.text
        b= a.strip()
        Company.append(b.replace("\n",""))
    
    for i in data:
        a = i.text
        Launching.append(a.split("Date")[1].split()[0])
        
    for i in data:
        a = i.text
        outlets.append(a.split('Outlets')[1].strip())    
        
    for i in data:
        a = i.text
        b = space.append(a.split('required')[1].split('\n')[1].strip())

    for i in data:
        a = i.text
        b = Investment.append(a.split("INR")[1].split('\n')[0])    
    

    for i in location:
        a = i.text
        hq.append(a.split('Headquarter')[1].split('\n')[1].strip())
# Out:
# https://www.franchiseindia.com/business-opportunities/fashion.m10?sortby=&page=1
# https://www.franchiseindia.com/business-opportunities/fashion.m10?sortby=&page=2
# https://www.franchiseindia.com/business-opportunities/fashion.m10?sortby=&page=3
# https://www.franchiseindia.com/business-opportunities/fashion.m10?sortby=&page=4
# https://www.franchiseindia.com/business-opportunities/fashion.m10?sortby=&page=5
# https://www.franchiseindia.com/business-opportunities/fashion.m10?sortby=&page=6
# https://www.franchiseindia.com/business-opportunities/fashion.m10?sortby=&page=7
# https://www.franchiseindia.com/business-opportunities/fashion.m10?sortby=&page=8
# https://www.franchiseindia.com/business-opportunities/fashion.m10?sortby=&page=9
# https://www.franchiseindia.com/business-opportunities/fashion.m10?sortby=&page=10
# https://www.franchiseindia.com/business-opportunities/fashion.m10?sortby=&page=11
# https://www.franchiseindia.com/business-opportunities/fashion.m10?sortby=&page=12
# ...

# %%
i = {"Company": Company,
    "Establishing Year": Establishment,
     "Launching Year": Launching,
     "Investment" : Investment,
     "Space Required" : space,
    "Outlets": outlets,
    "Headquarter" : hq}

# %%
print(len(Company))
print(len(Establishment))
print(len(Launching))
print(len(Min_Invest))
print(len(Max_Invest))
print(len(outlets))
print(len(minspace))
print(len(maxspace))
print(len(hq))
# Out:
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33
# 33

# %%
ii = pd.DataFrame(i)
ii
# Out:
#                                     Company Establishing Year Launching Year  \
# 0                                   ROOKIES              2009           2020
# 1                               Diwan Saheb              1957           2022
# 2                          PC Jeweller Ltd.              2005           2016
# 3                              Just In Time              2006           2021
# 4                                 Beatitude              2015           2022
# 5               Gem Selections: Khanna Gems              1987           2019
# 6                                Aaavio.com              2021           2022
# 7   Nandani Creation Limited (Jaipur Kurti)              2012           2022
# 8                             LABEL JAGRUTI              1990           2022
# 9                                  Ornazone              2022           2022
# 10                                 Specmart              2017           2020
# ...

# %%
ii.describe(include = 'all')
# Out:
#                             Company Establishing Year Launching Year  \
# count                            33                33             33
# unique                           33                26             13
# top     Gem Selections: Khanna Gems              1950           2022
# freq                              1                 3              9
#
#        Minimum Investment Maximum Investment       Outlets  \
# count                  33                 33            33
# unique                  9                  9            11
# top              10 Lac              20 Lac   Less than 10
# freq                    9                  9            17
#
#        Minimum Space (in sft) Maximum Space (in sft) Headquarter
# count                      33                     33          33
# unique                     19                     28          23
# top                       500              300 - 500      Mumbai
# ...

# %%
ii.head()
# Out:
#                        Company Establishing Year Launching Year  \
# 0  Gem Selections: Khanna Gems              1987           2019
# 1               PRATHAM SILVER              1985           2022
# 2                 Just In Time              2006           2021
# 3                  Diwan Saheb              1957           2022
# 4                    Beatitude              2015           2022
#
#   Minimum Investment Maximum Investment       Outlets Minimum Space (in sft)  \
# 0           10 Lac              20 Lac   Less than 10                     80
# 1             1 Cr                2 Cr   Less than 10                    400
# 2           50 Lac                1 Cr   Less than 10                    700
# 3           50 Lac                1 Cr   Less than 10                   3000
# 4           30 Lac              50 Lac   Less than 10                   1100
#
#   Maximum Space (in sft) Headquarter
# 0               80 - 100   New Delhi
# 1              400 - 500  Himatnagar
# ...

# %% [markdown]
# ### *Retail*

# %%
Company = []
Establishment = []
Launching = []
Investment= []
outlets = []
space = []
hq = []


for i in range(1,20):
    url = "https://www.franchiseindia.com/business-opportunities/retail.m9?sortby=&page="+str(i)
    print(url)
    
    page = requests.get(url)
    soup = BeautifulSoup(page.text)
    data = soup.find_all("div" , class_ = "commanmbsmobile")
    location = soup.find_all('div', class_ = "catdright pad20")
    companyname = soup.find_all("div", class_ = "catlist")
    
    for i in data:
        a = i.text
        Establishment.append(a.replace("\n","").split()[2])
        
    for i in companyname:
        a = i.text
        b= a.strip()
        Company.append(b.replace("\n",""))
           
   
    for i in data:
        a = i.text
        b = Investment.append(a.split("INR")[1].split('\n')[0])

    for i in data:
        a = i.text
        b = space.append(a.split('required')[1].split('\n')[1].strip()) 
    
    for i in data:
        a = i.text
        Launching.append(a.split("Date")[1].split()[0])
        
    for i in data:
        a = i.text
        outlets.append(a.split('Outlets')[1].strip())    
        

    for i in location:
        a = i.text
        hq.append(a.split('Headquarter')[1].split('\n')[1].strip())
# Out:
# https://www.franchiseindia.com/business-opportunities/retail.m9?sortby=&page=1
# https://www.franchiseindia.com/business-opportunities/retail.m9?sortby=&page=2
# https://www.franchiseindia.com/business-opportunities/retail.m9?sortby=&page=3
# https://www.franchiseindia.com/business-opportunities/retail.m9?sortby=&page=4
# https://www.franchiseindia.com/business-opportunities/retail.m9?sortby=&page=5
# https://www.franchiseindia.com/business-opportunities/retail.m9?sortby=&page=6
# https://www.franchiseindia.com/business-opportunities/retail.m9?sortby=&page=7
# https://www.franchiseindia.com/business-opportunities/retail.m9?sortby=&page=8
# https://www.franchiseindia.com/business-opportunities/retail.m9?sortby=&page=9
# https://www.franchiseindia.com/business-opportunities/retail.m9?sortby=&page=10
# https://www.franchiseindia.com/business-opportunities/retail.m9?sortby=&page=11
# https://www.franchiseindia.com/business-opportunities/retail.m9?sortby=&page=12
# ...

# %%
j ={"Company": Company,
    "Establishing Year": Establishment,
     "Launching Year": Launching,
     "Investment" : Investment,
     "Space Required" : space,
    "Outlets": outlets,
    "Headquarter" : hq}

# %%
print(len(Company))
print(len(Establishment))
print(len(Launching))
print(len(Investment))
print(len(space))

#print(len(Min_Invest))
#print(len(Max_Invest))
print(len(outlets))
#print(len(minspace))
#print(len(maxspace))
print(len(hq))
# Out:
# 73
# 73
# 73
# 73
# 73
# 73
# 73

# %%
jf = pd.DataFrame(j)
jf
# Out:
#                                               Company Establishing Year  \
# 0                                        Kuber Shoppe              2016
# 1                                           Berrylush              2018
# 2                                        RockingDeals              2002
# 3                                           Snackstar              2020
# 4                        Innovative Design Associates              2022
# ..                                                ...               ...
# 68                                            MW MART              2021
# 69                                            Blinkit              2016
# 70                             Siyaram Silk Mills Ltd              1978
# 71                           MIKHADI VILLAGE ARTISANS              2012
# 72  Door2Door - Dravidian eRetail Services Private...              2014
#
#    Launching Year           Investment Space Required       Outlets  \
# ...

# %%
jf.describe(include = 'all')
# Out:
#                                  Company Establishing Year Launching Year  \
# count                                 73                73             73
# unique                                73                32             18
# top     Sarvalaya Divine Private Limited              2020           2022
# freq                                   1                 8             29
#
#        Minimum Investment Maximum Investment       Outlets  \
# count                  73                 73            73
# unique                 12                 11             7
# top              20 Lac              30 Lac   Less than 10
# freq                   17                 17            45
#
#        Minimum Space (in sft) Maximum Space (in sft) Headquarter
# count                      73                     73          73
# unique                     27                     56          33
# top                      1000            1500 - 3000   Faridabad
# ...

# %%
jf.head()
# Out:
#                             Company Establishing Year Launching Year  \
# 0  Sarvalaya Divine Private Limited              1977           2022
# 1                    Masonite Doors              2009           2020
# 2                        Idecorwala              2010           2022
# 3                    Sports Station              2005           2011
# 4                    AKI Fresh Mart              2000           2022
#
#   Minimum Investment Maximum Investment       Outlets Minimum Space (in sft)  \
# 0           30 Lac              50 Lac   Less than 10                    500
# 1            10000                50 K   Less than 10                    300
# 2           10 Lac              20 Lac   Less than 10                  -N/A-
# 3           50 Lac                1 Cr         50-100                   1500
# 4           30 Lac              50 Lac         50-100                    600
#
#   Maximum Space (in sft)    Headquarter
# 0             500 - 2500  Visakhapatnam
# ...

# %%
jf
# Out:
#                                               Company Establishing Year  \
# 0                    Sarvalaya Divine Private Limited              1977
# 1                                      Masonite Doors              2009
# 2                                          Idecorwala              2010
# 3                                      Sports Station              2005
# 4                                      AKI Fresh Mart              2000
# ..                                                ...               ...
# 68           Manak Waste Management Pvt Ltd (Cashify)              2015
# 69                              XIMIVOGUE TRADING LLP              2018
# 70                                            Blinkit              2016
# 71                                           24 Seven              2000
# 72  Door2Door - Dravidian eRetail Services Private...              2014
#
#    Launching Year Minimum Investment Maximum Investment       Outlets  \
# ...

# %% [markdown]
# ### *Hotel, Travel and Tourism*

# %%
Company = []
Establishment = []
Launching = []
Investment= []
outlets = []
space = []
hq = []


for i in range(1,5):
    url = "https://www.franchiseindia.com/business-opportunities/hotels-and-resorts.m263?sortby=&page="+str(i)
    print(url)
    
    page = requests.get(url)
    soup = BeautifulSoup(page.text)
    data = soup.find_all("div" , class_ = "commanmbsmobile")
    location = soup.find_all('div', class_ = "catdright pad20")
    companyname = soup.find_all("div", class_ = "catlist")
    
    for i in data:
        a = i.text
        Establishment.append(a.replace("\n","").split()[2])
        
    for i in companyname:
        a = i.text
        b= a.strip()
        Company.append(b.replace("\n",""))
           
  
    for i in data:
        a = i.text
        Launching.append(a.split("Date")[1].split()[0])
        
    for i in data:
        a = i.text
        outlets.append(a.split('Outlets')[1].strip())    
        
    for i in data:
        a = i.text
        b = space.append(a.split('required')[1].split('\n')[1].strip())

    for i in data:
        a = i.text
        b = Investment.append(a.split("INR")[1].split('\n')[0])

    for i in location:
        a = i.text
        hq.append(a.split('Headquarter')[1].split('\n')[1].strip())
# Out:
# https://www.franchiseindia.com/business-opportunities/hotels-and-resorts.m263?sortby=&page=1
# https://www.franchiseindia.com/business-opportunities/hotels-and-resorts.m263?sortby=&page=2
# https://www.franchiseindia.com/business-opportunities/hotels-and-resorts.m263?sortby=&page=3
# https://www.franchiseindia.com/business-opportunities/hotels-and-resorts.m263?sortby=&page=4

# %%
k = {"Company": Company,
    "Establishing Year": Establishment,
     "Launching Year": Launching,
     "Investment" : Investment,
     "Space Required" : space,
    "Outlets": outlets,
    "Headquarter" : hq}

# %%
kf = pd.DataFrame(k)
kf
# Out:
#                      Company Establishing Year Launching Year  \
# 0              Neem Holidays              2001           2022
# 1  Ajay ModiTravels Pvt. Ltd              1997           2022
#
#            Investment Space Required       Outlets    Headquarter
# 0    5 Lac  - 10 Lac       250 - 250  Less than 10  Goregaon east
# 1    5 Lac  - 10 Lac       250 - 300  Less than 10      Ahmedabad

# %% [markdown]
# ### *Home Based Business*

# %%
Company = []
Establishment = []
Launching = []
Investment= []
outlets = []
space = []
hq = []


for i in range(1,5):
    url = "https://www.franchiseindia.com/business-opportunities/home-based-business.m7?sortby=&page="+str(i)
    print(url)
    
    page = requests.get(url)
    soup = BeautifulSoup(page.text)
    data = soup.find_all("div" , class_ = "commanmbsmobile")
    location = soup.find_all('div', class_ = "catdright pad20")
    companyname = soup.find_all("div", class_ = "catlist")
    
    for i in data:
        a = i.text
        Establishment.append(a.replace("\n","").split()[2])
        
    for i in companyname:
        a = i.text
        b= a.strip()
        Company.append(b.replace("\n",""))
           
   
    for i in data:
        a = i.text
        Launching.append(a.split("Date")[1].split()[0])
        
    for i in data:
        a = i.text
        outlets.append(a.split('Outlets')[1].strip())    

    for i in data:
        a = i.text
        b = space.append(a.split('required')[1].split('\n')[1].strip())

    for i in data:
        a = i.text
        b = Investment.append(a.split("INR")[1].split('\n')[0])

    for i in location:
        a = i.text
        hq.append(a.split('Headquarter')[1].split('\n')[1].strip())
# Out:
# https://www.franchiseindia.com/business-opportunities/home-based-business.m7?sortby=&page=1
# https://www.franchiseindia.com/business-opportunities/home-based-business.m7?sortby=&page=2
# https://www.franchiseindia.com/business-opportunities/home-based-business.m7?sortby=&page=3
# https://www.franchiseindia.com/business-opportunities/home-based-business.m7?sortby=&page=4

# %%
l = {"Company": Company,
    "Establishing Year": Establishment,
     "Launching Year": Launching,
     "Investment" : Investment,
     "Space Required" : space,
    "Outlets": outlets,
    "Headquarter" : hq}

# %%
lf = pd.DataFrame(l)
lf
# Out:
#                  Company Establishing Year Launching Year  \
# 0          House of Cure              2020           2022
# 1              Rentomojo              2014           2022
# 2                Collins              1986           2022
# 3  South Indian Junction              2017           2020
# 4         FBI industries              1999           2021
#
#             Investment Space Required       Outlets  Headquarter
# 0      50 Lac  - 1 Cr     1000 - 2000  Less than 10       Mumbai
# 1    20 Lac  - 30 Lac        00 - 000       100-200    Bangalore
# 2      50 Lac  - 1 Cr     2000 - 3000  Less than 10       Mumbai
# 3       50 K  - 2 Lac       400 - 500  Less than 10  Pondicherry
# 4    20 Lac  - 30 Lac     1000 - 3000  Less than 10    Deharaudn

# %%
sf = pd.concat((lf,kf,jf,hf,ii,gf),axis = 0)
sf
# Out:
#                          Company Establishing Year Launching Year  \
# 0                  House of Cure              2020           2022
# 1                      Rentomojo              2014           2022
# 2                        Collins              1986           2022
# 3          South Indian Junction              2017           2020
# 4                 FBI industries              1999           2021
# ..                           ...               ...            ...
# 9           Eos Cinemas Pvt. Ltd              2013           2015
# 10  SGL MINIPLEX PRIVATE LIMITED              2020           2020
# 11                      ResQRoom              2016           2018
# 12      House of Fitness pvt ltd              2012           2012
# 13               All Things love              2016           2020
#
#              Investment Space Required       Outlets  Headquarter
# 0       50 Lac  - 1 Cr     1000 - 2000  Less than 10       Mumbai
# ...

# %%
sf.drop(columns = 'Maximum Space (in sft)', inplace = True)
sf
# Out:
#                          Company Establishing Year Launching Year  \
# 0                      Rentomojo              2014           2022
# 1                  House of Cure              2020           2022
# 2                        Collins              1986           2022
# 3          South Indian Junction              2017           2020
# 4                 FBI industries              1999           2021
# ..                           ...               ...            ...
# 9   SGL MINIPLEX PRIVATE LIMITED              2020           2020
# 10          Eos Cinemas Pvt. Ltd              2013           2015
# 11                      ResQRoom              2016           2018
# 12      House of Fitness pvt ltd              2012           2012
# 13               All Things love              2016           2020
#
#    Minimum Investment Maximum Investment       Outlets Minimum Space (in sft)  \
# 0            20 Lac              30 Lac        100-200                     00
# ...

# %%
sf.reset_index(inplace = True)
sf.drop('index', axis = 1, inplace = True)
sf
# Out:
#                           Company Establishing Year Launching Year  \
# 0                       Rentomojo              2014           2022
# 1                   House of Cure              2020           2022
# 2                         Collins              1986           2022
# 3           South Indian Junction              2017           2020
# 4                  FBI industries              1999           2021
# ..                            ...               ...            ...
# 197  SGL MINIPLEX PRIVATE LIMITED              2020           2020
# 198          Eos Cinemas Pvt. Ltd              2013           2015
# 199                      ResQRoom              2016           2018
# 200      House of Fitness pvt ltd              2012           2012
# 201               All Things love              2016           2020
#
#     Minimum Investment Maximum Investment       Outlets  \
# 0             20 Lac              30 Lac        100-200
# ...

# %%
sf.head()
# Out:
#                  Company Establishing Year Launching Year Minimum Investment  \
# 0              Rentomojo              2014           2022           20 Lac
# 1          House of Cure              2020           2022           50 Lac
# 2                Collins              1986           2022           50 Lac
# 3  South Indian Junction              2017           2020             50 K
# 4         FBI industries              1999           2021           20 Lac
#
#   Maximum Investment       Outlets Minimum Space (in sft)  Headquarter
# 0            30 Lac        100-200                     00    Bangalore
# 1              1 Cr   Less than 10                   1000       Mumbai
# 2              1 Cr   Less than 10                   2000       Mumbai
# 3             2 Lac   Less than 10                    400  Pondicherry
# 4            30 Lac   Less than 10                   1000    Deharaudn

# %%
tf = pd.concat((bf,ef,ff),axis = 0)
tf
# Out:
#                                               Company Establishing Year  \
# 0                                     What a Sandwich              2013
# 1                                          Go69 Pizza              2015
# 2                                         THE GRANIOS              2013
# 3                                       CHICAGO PIZZA              2000
# 4                                           Brewbakes              2014
# ..                                                ...               ...
# 86                  Medlife Pharma healthcare Pvt Ltd              2014
# 87                                      Framekart.com              1995
# 88  Max Lab, A Division of Max Healthcare Institut...              2016
# 89                                         NephroPlus              2009
# 90                                         Ayouthveda              2020
#
#    Launching Year           Investment Space Required       Outlets  \
# ...

# %%
tf.reset_index(inplace = True)
tf.drop('index', axis = 1, inplace = True)
tf
# Out:
#                                                Company Establishing Year  \
# 0                                      What a Sandwich              2013
# 1                                           Go69 Pizza              2015
# 2                                          THE GRANIOS              2013
# 3                                        CHICAGO PIZZA              2000
# 4                                            Brewbakes              2014
# ..                                                 ...               ...
# 255                  Medlife Pharma healthcare Pvt Ltd              2014
# 256                                      Framekart.com              1995
# 257  Max Lab, A Division of Max Healthcare Institut...              2016
# 258                                         NephroPlus              2009
# 259                                         Ayouthveda              2020
#
#     Launching Year           Investment Space Required       Outlets  \
# ...

# %%
tf.drop('Maximum Space (in sft)', axis = 1, inplace = True)
tf
# Out:
#                                                Company Establishing Year  \
# 0                                      What a Sandwich              2013
# 1                                           Go69 Pizza              2015
# 2                                          THE GRANIOS              2013
# 3                                        CHICAGO PIZZA              2000
# 4                                           U.S. Pizza              1998
# ..                                                 ...               ...
# 253  Max Lab, A Division of Max Healthcare Institut...              2016
# 254                         The Kerala Ayurveda Centre              2002
# 255                                      Framekart.com              1995
# 256                                         NephroPlus              2009
# 257                                         Ayouthveda              2020
#
#     Launching Year Minimum Investment Maximum Investment       Outlets  \
# ...

# %%
df = pd.concat((tf,sf), axis = 0)
df
# Out:
#                          Company Establishing Year Launching Year  \
# 0                What a Sandwich              2013           2018
# 1                     Go69 Pizza              2015           2016
# 2                    THE GRANIOS              2013           2017
# 3                  CHICAGO PIZZA              2000           2007
# 4                      Brewbakes              2014           2015
# ..                           ...               ...            ...
# 9           Eos Cinemas Pvt. Ltd              2013           2015
# 10  SGL MINIPLEX PRIVATE LIMITED              2020           2020
# 11                      ResQRoom              2016           2018
# 12      House of Fitness pvt ltd              2012           2012
# 13               All Things love              2016           2020
#
#              Investment Space Required       Outlets Headquarter
# 0       2 Lac  - 5 Lac      200 - 1300       100-200        Pune
# ...

# %%
df.reset_index(inplace = True)
df.drop('index', axis = 1, inplace = True)
df
# Out:
#                           Company Establishing Year Launching Year  \
# 0                 What a Sandwich              2013           2018
# 1                      Go69 Pizza              2015           2016
# 2                     THE GRANIOS              2013           2017
# 3                   CHICAGO PIZZA              2000           2007
# 4                       Brewbakes              2014           2015
# ..                            ...               ...            ...
# 458          Eos Cinemas Pvt. Ltd              2013           2015
# 459  SGL MINIPLEX PRIVATE LIMITED              2020           2020
# 460                      ResQRoom              2016           2018
# 461      House of Fitness pvt ltd              2012           2012
# 462               All Things love              2016           2020
#
#               Investment Space Required       Outlets Headquarter
# 0        2 Lac  - 5 Lac      200 - 1300       100-200        Pune
# ...

# %%
df
# Out:
#                           Company Establishing Year Launching Year  \
# 0                 What a Sandwich              2013           2018
# 1                      Go69 Pizza              2015           2016
# 2                     THE GRANIOS              2013           2017
# 3                   CHICAGO PIZZA              2000           2007
# 4                       Brewbakes              2014           2015
# ..                            ...               ...            ...
# 458          Eos Cinemas Pvt. Ltd              2013           2015
# 459  SGL MINIPLEX PRIVATE LIMITED              2020           2020
# 460                      ResQRoom              2016           2018
# 461      House of Fitness pvt ltd              2012           2012
# 462               All Things love              2016           2020
#
#               Investment Space Required       Outlets Headquarter
# 0        2 Lac  - 5 Lac      200 - 1300       100-200        Pune
# ...

# %% [markdown]
# # CLEANING

# %%
df["Minimum Investment"] = df["Minimum Investment"].str.replace('Lac','Lakh')
df
# Out:
#                           Company Establishing Year Launching Year  \
# 0                 What a Sandwich              2013           2018
# 1                      Go69 Pizza              2015           2016
# 2                     THE GRANIOS              2013           2017
# 3                   CHICAGO PIZZA              2000           2007
# 4                      U.S. Pizza              1998           2002
# ..                            ...               ...            ...
# 455  SGL MINIPLEX PRIVATE LIMITED              2020           2020
# 456          Eos Cinemas Pvt. Ltd              2013           2015
# 457                      ResQRoom              2016           2018
# 458      House of Fitness pvt ltd              2012           2012
# 459               All Things love              2016           2020
#
#     Minimum Investment Maximum Investment       Outlets  \
# 0               50 K              2 Lakh        100-200
# ...

# %%
df["Maximum Investment"] = df["Maximum Investment"].str.replace('Lac','Lakh')
df
# Out:
#                           Company Establishing Year Launching Year  \
# 0                 What a Sandwich              2013           2018
# 1                      Go69 Pizza              2015           2016
# 2                     THE GRANIOS              2013           2017
# 3                   CHICAGO PIZZA              2000           2007
# 4                      U.S. Pizza              1998           2002
# ..                            ...               ...            ...
# 455  SGL MINIPLEX PRIVATE LIMITED              2020           2020
# 456          Eos Cinemas Pvt. Ltd              2013           2015
# 457                      ResQRoom              2016           2018
# 458      House of Fitness pvt ltd              2012           2012
# 459               All Things love              2016           2020
#
#     Minimum Investment Maximum Investment       Outlets  \
# 0               50 K              2 Lakh        100-200
# ...

# %%
df["Minimum Space (in sft)"].value_counts()
# Out:
# 200           40
# 500           38
# 300           34
# 1500          33
# 100           32
# 1000          32
# 150           24
# -N/A-         23
# 800           21
# 250           14
# 400           14
# 600           14
# 1200          11
# 2000          11
# 3000          10
# 700           10
# 00             9
# 5000           8
# 2500           8
# 000            7
# 50             7
# 350            5
# 900            5
# 1100           4
# 1600           3
# 4000           3
# 10             3
# 3500           3
# 80             2
# 10000          2
# 70             2
# 6000           2
# 1300           2
# 650            2
# 60             2
# 450            1
# 1500sqft       1
# 150-300        1
# 850            1
# 400-600        1
# 65000          1
# 65340          1
# 8000           1
# None           1
# 01             1
# 1800           1
# 1330           1
# commercial     1
# 120            1
# 550            1
# 1700           1
# 12000          1
# ...

# %%
df2['price']=df2['price'].astype("int")

# %%
df["Minimum Space (in sft)"] = df["Minimum Space (in sft)"].replace({'-N/A-': np.NaN})
#df["Minimum Space (in sft)"].fillna(method = 'bfill')
df
# Out:
#                           Company Establishing Year Launching Year  \
# 0                 What a Sandwich              2013           2018
# 1                      Go69 Pizza              2015           2016
# 2                     THE GRANIOS              2013           2017
# 3                   CHICAGO PIZZA              2000           2007
# 4                      U.S. Pizza              1998           2002
# ..                            ...               ...            ...
# 455  SGL MINIPLEX PRIVATE LIMITED              2020           2020
# 456          Eos Cinemas Pvt. Ltd              2013           2015
# 457                      ResQRoom              2016           2018
# 458      House of Fitness pvt ltd              2012           2012
# 459               All Things love              2016           2020
#
#     Minimum Investment Maximum Investment       Outlets  \
# 0               50 K              2 Lakh        100-200
# ...

# %%
df['Minimum Space (in sft)'].fillna(method ='bfill', inplace = True)
df
# Out:
#                           Company Establishing Year Launching Year  \
# 0                 What a Sandwich              2013           2018
# 1                      Go69 Pizza              2015           2016
# 2                     THE GRANIOS              2013           2017
# 3                   CHICAGO PIZZA              2000           2007
# 4                      U.S. Pizza              1998           2002
# ..                            ...               ...            ...
# 455  SGL MINIPLEX PRIVATE LIMITED              2020           2020
# 456          Eos Cinemas Pvt. Ltd              2013           2015
# 457                      ResQRoom              2016           2018
# 458      House of Fitness pvt ltd              2012           2012
# 459               All Things love              2016           2020
#
#     Minimum Investment Maximum Investment       Outlets  \
# 0               50 K              2 Lakh        100-200
# ...

# %%
df["Minimum Space (in sft)"] = df["Minimum Space (in sft)"].replace({'400-600': np.NaN,'1000-1500': np.NaN,'150-300': np.NaN,'commercial': np.NaN})
df
# Out:
#                           Company Establishing Year Launching Year  \
# 0                 What a Sandwich              2013           2018
# 1                      Go69 Pizza              2015           2016
# 2                     THE GRANIOS              2013           2017
# 3                   CHICAGO PIZZA              2000           2007
# 4                      U.S. Pizza              1998           2002
# ..                            ...               ...            ...
# 455  SGL MINIPLEX PRIVATE LIMITED              2020           2020
# 456          Eos Cinemas Pvt. Ltd              2013           2015
# 457                      ResQRoom              2016           2018
# 458      House of Fitness pvt ltd              2012           2012
# 459               All Things love              2016           2020
#
#     Minimum Investment Maximum Investment       Outlets  \
# 0               50 K              2 Lakh        100-200
# ...

# %%
df['Minimum Space (in sft)'].fillna(df['Minimum Space (in sft)'].mode()[0], inplace = True)
df
# Out:
#                           Company Establishing Year Launching Year  \
# 0                 What a Sandwich              2013           2018
# 1                      Go69 Pizza              2015           2016
# 2                     THE GRANIOS              2013           2017
# 3                   CHICAGO PIZZA              2000           2007
# 4                      U.S. Pizza              1998           2002
# ..                            ...               ...            ...
# 455  SGL MINIPLEX PRIVATE LIMITED              2020           2020
# 456          Eos Cinemas Pvt. Ltd              2013           2015
# 457                      ResQRoom              2016           2018
# 458      House of Fitness pvt ltd              2012           2012
# 459               All Things love              2016           2020
#
#     Minimum Investment Maximum Investment       Outlets  \
# 0               50 K              2 Lakh        100-200
# ...

# %%
df['Minimum Space (in sft)'].value_counts()
# Out:
# 200      57
# 500      40
# 300      38
# 1500     37
# 100      36
# 1000     34
# 150      24
# 800      24
# 250      16
# 400      15
# 2000     14
# 600      14
# 700      12
# 1200     12
# 3000     10
# 2500      9
# 5000      8
# 900       7
# 1100      5
# 350       5
# 1600      4
# 3500      3
# 4000      3
# 65000     3
# 60        2
# 120       2
# 6000      2
# 550       2
# 10000     2
# 1300      2
# 80        2
# 650       2
# 70        2
# 12000     1
# 1800      1
# 1330      1
# 01        1
# 1350      1
# 8000      1
# 65340     1
# 1700      1
# 850       1
# 450       1
# None      1
# 750       1
# Name: Minimum Space (in sft), dtype: int64

# %%
df.isnull().sum()
# Out:
# Company                   0
# Establishing Year         0
# Launching Year            0
# Minimum Investment        0
# Maximum Investment        0
# Outlets                   0
# Minimum Space (in sft)    0
# Headquarter               0
# dtype: int64

# %%
df
# Out:
#                           Company Establishing Year Launching Year  \
# 0                 What a Sandwich              2013           2018
# 1                      Go69 Pizza              2015           2016
# 2                     THE GRANIOS              2013           2017
# 3                   CHICAGO PIZZA              2000           2007
# 4                      U.S. Pizza              1998           2002
# ..                            ...               ...            ...
# 455  SGL MINIPLEX PRIVATE LIMITED              2020           2020
# 456          Eos Cinemas Pvt. Ltd              2013           2015
# 457                      ResQRoom              2016           2018
# 458      House of Fitness pvt ltd              2012           2012
# 459               All Things love              2016           2020
#
#     Minimum Investment Maximum Investment       Outlets  \
# 0               50 K              2 Lakh        100-200
# ...

# %%
# Out:
# 'C:\\Users\\Mukesh Anchuri'

# %%
df.to_csv("Franchise India.csv")

# %%
df
# Out:
#                           Company Establishing Year Launching Year  \
# 0                 What a Sandwich              2013           2018
# 1                      Go69 Pizza              2015           2016
# 2                     THE GRANIOS              2013           2017
# 3                   CHICAGO PIZZA              2000           2007
# 4                      U.S. Pizza              1998           2002
# ..                            ...               ...            ...
# 455  SGL MINIPLEX PRIVATE LIMITED              2020           2020
# 456          Eos Cinemas Pvt. Ltd              2013           2015
# 457                      ResQRoom              2016           2018
# 458      House of Fitness pvt ltd              2012           2012
# 459               All Things love              2016           2020
#
#     Minimum Investment Maximum Investment       Outlets  \
# 0               50 K              2 Lakh        100-200
# ...

# %%
for i in data2:
    a = i.text
    b = Investment.append(a.split("INR")[1].split('\n')[0])
    
for i in data2:
    a = i.text
    b = space.append(a.split('required')[1].split('\n')[1].strip())
# Out:
# ['100 - 800',
#  '200 - 250',
#  '200 - 1300',
#  '100 - 150',
#  '250 - 1000',
#  '500 - 2000',
#  '100 - 5000',
#  '100 - 1000',
#  '100 - 1000',
#  '800 - 1000',
#  '100 - 500',
#  '250 - 400',
#  '100 - 300',
#  '00 - 000',
#  '250 - 2000',
#  '1200 - 1500',
#  '150 - 300',
#  '-N/A-',
#  '300 - 2000',
#  '100 - 400',
#  '200 - 400']

# %%
Investment = []
for i in data2:
    a = i.text
    b = Investment.append(a.split("INR")[1].split('\n')[0])
Investment
# Out:
# ['  5 Lac  - 10 Lac ',
#  '  50 K  - 2 Lac ',
#  '  2 Lac  - 5 Lac ',
#  '  10 Lac  - 20 Lac ',
#  '  20 Lac  - 30 Lac ',
#  '  30 Lac  - 50 Lac ',
#  '  5 Lac  - 10 Lac ',
#  '  10 Lac  - 20 Lac ',
#  '  10 Lac  - 2 Cr ',
#  '  50 Lac  - 1 Cr ',
#  '  5 Lac  - 10 Lac ',
#  '  10 Lac  - 20 Lac ',
#  '  10 Lac  - 20 Lac ',
#  '  10 Lac  - 20 Lac ',
#  '  50 Lac  - 1 Cr ',
#  '  1 Cr  - 2 Cr ',
#  '  10 Lac  - 20 Lac ',
#  '  30 Lac  - 50 Lac ',
#  '  10 Lac  - 20 Lac ',
#  '  2 Lac  - 5 Lac ',
#  '  10 Lac  - 20 Lac ']
